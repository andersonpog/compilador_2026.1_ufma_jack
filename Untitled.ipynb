# %%
# !python main.py Main
# Out:
# Realizando análise léxica do arquivo Main.jack
# ...

# %%
# !pytest tests/test_scanner.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.13.9, pytest-8.4.2, pluggy-1.5.0 -- C:\Users\Jeys Almone\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: C:\Users\Jeys Almone\compilador_2026.1_ufma_jack
# plugins: anyio-4.10.0
# collecting ... collected 2 items
#
# tests/test_scanner.py::test_numero_basico PASSED                         [ 50%]
# tests/test_scanner.py::test_string_basica PASSED                         [100%]
#
# ============================== 2 passed in 0.05s ==============================
